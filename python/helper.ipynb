# %%
import requests
import pandas as pd

# %%
res = requests.get('http://localhost:3000/phrases')
df = pd.DataFrame(res.json())

# %%
df['phrase'] = df['portuguese'] + '\n' + df['english']
res = df.drop(columns=['id', 'portuguese', 'english'])

res
# Out:
#                                      audio            tags           type  \
# 0    http://localhost:3000/phrases/1/audio  [homem-aranha]    TRANSLATION
# 1    http://localhost:3000/phrases/2/audio  [homem-aranha]    TRANSLATION
# 2    http://localhost:3000/phrases/4/audio          [test]    TRANSLATION
# 3   http://localhost:3000/phrases/10/audio            [01]    TRANSLATION
# 4   http://localhost:3000/phrases/13/audio            [t3]       NEGATIVE
# 5   http://localhost:3000/phrases/14/audio            [01]    TRANSLATION
# 6   http://localhost:3000/phrases/29/audio            [01]          STORY
# 7   http://localhost:3000/phrases/30/audio          [test]    TRANSLATION
# 8   http://localhost:3000/phrases/31/audio          [test]    TRANSLATION
# 9   http://localhost:3000/phrases/32/audio          [test]    TRANSLATION
# 10  http://localhost:3000/phrases/35/audio            [t1]    TRANSLATION
# 11  http://localhost:3000/phrases/36/audio           [cor]    TRANSLATION
# ...
